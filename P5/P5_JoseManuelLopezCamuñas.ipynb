# %% [markdown]
# ==============================================================================================
# ## Practicum 5: Image search using textures
# ==============================================================================================
#
#
#
# The exercises of this notebook will show how we can perform image similarity search using:
#
# - Gaussian filters
# - Descriptors based on texture and color
#
# #### Problem we want to solve
# - Given a query image **$x$** and a set of images **$X$** we would like to retreive the most similar to **$x$** images from  **$X$**.

# %% [markdown]
# ## Delivery
#
# All code sould be commented in English. Answers of the questions should be given in English too.
#
# Compressed file **P5_Student1_Student2.zip** that includes:
# - The notebook P5_Student1_Student2.ipynb completed with the solutions to the exercises and their corresponding comments.
# - The images used that are not provided in P5.zip.
#
# **Deadline (Campus Virtual): Desember 12th, 11:00 p.m.**

# %% [markdown]
#  The function should return a feature vector obtained by averaging each filter response on the image.
#
# **Hint**: Note that since at this moment we are focusing on the texture, we will not use the color of the images.

# %% [markdown]
# ## Looking at the images

# %%
# %matplotlib inline

import time
import scipy
import numpy as np
import skimage
from skimage import filters
from skimage import io
from skimage.color import rgb2gray
import os
from scipy.ndimage import convolve

import matplotlib.pyplot as plt

# %%
path = "./images/texturesimages/buildings/"
building_images = [skimage.io.imread(path + f) for f in os.listdir(path)]

path = "./images/texturesimages/forest/"
forest_images = [skimage.io.imread(path + f) for f in os.listdir(path)]

path = "./images/texturesimages/sunset/"
sunset_images = [skimage.io.imread(path + f) for f in os.listdir(path)]

# %%
fig, ax= plt.subplots(ncols=3, nrows=1, figsize=(20,30))

ax[0].imshow(sunset_images[0])
ax[1].imshow(forest_images[0])
ax[2].imshow(building_images[0])
plt.show()

# %%
len(sunset_images), len(forest_images), len(sunset_images)
# Out:
# (30, 30, 30)

# %% [markdown]
# # Filter banks
#
# We can apply a collection of multiple filters that we call a filter bank. Note that if we apply $D$ filters our feature vectors will be $D$ dimensional.
#
# The following image shows a filter bank. In the filter bank we typically want filters to capture a combination of scales, orientations of different types of patterns. This particular filter bank is The Leung-Malik (LM) Filter Bank.
#
# <img src="./images_notebook/filter_bank.png">

# %% [markdown]
# ## Leung-Malik (LM) Filter Bank

# %%
import LM_filters
# Out:
# LM filters imported, the shape of the filter bank is:  (49, 49, 48)

# %%
filter_bank = LM_filters.makeLMfilters()
filter_bank.shape
# Out:
# (49, 49, 48)

# %% [markdown]
# ### Plotting all filters

# %%
n_filters = filter_bank.shape[-1]

fig, ax = plt.subplots(ncols=12, nrows=4, figsize=(15,3))

k = 0
for i in range(4):
    for j in range(12):
        ax[i,j].imshow(filter_bank[:,:,k], cmap = 'gray')
        ax[i,j].axis("off")
        k = k + 1

# %% [markdown]
# ## Exercise 5.1 Plot the convolved image by some of the filters
#
#
# Make a function `visualize_features(im,  filter_bank, n_filters=5)` that recieves the `filter_bank`, an image `im` and an integer `n_filters`.
#
# The function  must make a plot of two rows containing in the first row, in position $k$, the image convolved by filter $k$. In the second row, in position $k$, the image of the k'th filter. The result for `n_filter=5` should look like
#
#
# <img src="./images/filters.png">

# %%
im = building_images[0]
im = skimage.color.rgb2gray(building_images[0])
plt.imshow(im, cmap="gray")

# %%
def visualize_features(im,  filter_bank, n_filters=5):
    fig, ax = plt.subplots(ncols=n_filters, nrows=2, figsize=(15,7))#create plots
    
    for i in range(n_filters):
        mask = filter_bank[:,:,i]#filter as mask
        filt_image = convolve(im,mask)#aplting convolvulation with filter
        ax[0][i].imshow(filt_image,cmap="gray")#plot image
        
    for i in range(n_filters):
        ax[1][i].imshow(filter_bank[:,:,i],cmap="gray")#plot used filter
    
    plt.show()
    
visualize_features(im, filter_bank)

# %% [markdown]
# ## Exercise 5.2 Constructing a feature vector for a given image
#
#
# Given $D$ filters from the filter bank and a single image `image`, make a function `features_from_filter_bank(image, filter_bank, n_filters)` that returns a feature vector of shape `n_filters`. The returned vector must contain at position $k$ the mean of the absolute value of the convolved image by filter $k$.
#
# $$
# \text{feat}(x) = \left( \text{mean}( |r_1|), \dots,\text{mean}(|r_D|) \right)
# $$

# %%
im = skimage.color.rgb2gray(building_images[0])

def features_from_filter_bank(image, filter_bank, n_filters):
    ## Complete this function
    im_conv = np.zeros(image.shape)
    features_for_im = np.zeros(n_filters)#feat vector
    
    for i in range(n_filters):
        mask = filter_bank[:,:,i]#filter
        filt_image = convolve(image,mask)#aplying filter
        features_for_im[i] = np.abs(np.mean(filt_image))#creating feature vector
        
  
    return features_for_im

features_for_im = features_from_filter_bank(im, filter_bank, n_filters)

# %% [markdown]
# ## Exercise 5.3 Constructing the matrix of the feature vectors for all images
#
# Implement a function `get_class_Features(all_images, filter_bank)` that applies `features_from_filter_bank` to get a feature vector for each of the images in the union of the three datasets (forest, buildings, sunset). It must return a matrix containing at row $k$ feature vector for the input image $k$.
#
#
# Wall time: 7min 49s

# %%
all_images = building_images + forest_images + sunset_images

# %%
# %%time

def get_class_features(all_images,  filter_bank):

    n_images = len(all_images)
    n_filters = filter_bank.shape[-1]
    all_feature_vectors=np.zeros((n_images,filter_bank.shape[-1]))#matrix of feature vectors
    for i in range(n_images):
        all_feature_vectors[i] = features_from_filter_bank(rgb2gray(all_images[i]),filter_bank,n_filters)
        #create feature vector of every image and insert into the matrix
    return all_feature_vectors

all_feature_vectors=get_class_features(all_images,  filter_bank)
# Out:
# CPU times: user 8min 59s, sys: 37 s, total: 9min 36s
# Wall time: 9min 36s

# %% [markdown]
# ## Exercise 5.4 Visualizing the features of an image
#
# Define a function `visualize_features` that given a feature index and an array containing all feature vectors, plots its values for the three datasets using different colors for each dataset (in total plots should contain 3 colors).

# %%
def visualize_features(k, all_feature_vectors):
    feat1 = all_feature_vectors[:,k-1][:30]#class1
    feat2 = all_feature_vectors[:,k-1][30:60]#class2
    feat3 = all_feature_vectors[:,k-1][60:90]#class3
    
 
    plt.plot(feat1, '*', color=[1, 0, 0]) # Red stars
    plt.plot(feat2, 'o', color=[0, 1, 0]) # Green dots
    plt.plot(feat3, 'x', color=[0, 0, 1]) # Blue cross
    plt.show()

visualize_features(25, all_feature_vectors)    
visualize_features(41, all_feature_vectors)

# %% [markdown]
# #### Similarity search
#
# Let us assume $f(x) \in \mathbb{R}^D$ represents a set of features for $x$. Given a query image $x$ and another image $x^m$ from the database, we can compute the distance between images as
# $$
# \text{distance}\left( f(x) , \, f(x^m) \right) = \| \text{feat}(x)  - \text{feat}(x^m)  \|_2 =  \sqrt{ \sum_{d=1}^\text{D} \left( f(x)_d - f(x^m)_d  \right)^2 }
# $$
#
# then we can find the closest image $x^{m^*}$ from the database to $x$ as $m^* =  \text{argmin}_{m} \{ \| \text{feat}(x)  - \text{feat}(x^m)  \|_2 \}$
#
#
# ## Exercise 5.5 Retrieving the most similar images
#
#
#
# Implement a function `retrieve_k_images_from_X(query, X, k)` where `query` is an image,  `X` ins the array containing the features from all the images and  `k` is an integer. The function should retrieve the `k` most similar images (according to the l2 norm) and the distances from the closest images to the query image. You can include the query image since it is in `X`.
#
# - Make a plot with the first column beeing the query image and the other k columns the closest images in the feature space.

# %%
X = np.array(all_feature_vectors)
ind_1 = 6
ind_2 = 30
ind_3 = 65

query_1 = X[6, :]
query_2 = X[30,:]
query_3 = X[65,:]


# Display the query images
fig, ax = plt.subplots(ncols=3, nrows=1, figsize=(15,3))
ax[0].imshow(all_images[6]) 
ax[1].imshow(all_images[30])
ax[2].imshow(all_images[65])

# %%
def retrieve_k_images_from_X(query, X, k):
    #Complete
    distances = []
    closest_to_query = None
    closest_images =None
    q = None
    for i in range(len(X)):#check every image
        if(np.array_equal(query,X[i])):#its the same that we query?
            q = all_images[i],i#pointer
        dist = np.linalg.norm(np.abs(query - X[i]))#calculate dist
        distances.append(dist)
        
    k_closests = list(np.argpartition(distances, k)[:k])#min k index 
    aux = [(distances[k],k) for k in k_closests]#distance,k index 
    aux.sort()#sorting them
    closests_images = [all_images[item[1]] for item in aux]#closest images based on sort
    return closests_images,aux,q[0],distances

def plot_retrieve(closests_images,aux,query,distances):#ploting
    fig, ax = plt.subplots(ncols=len(closests_images)+1, nrows=1, figsize=(15,3))
    ax[0].imshow(query)
    ax[0].title.set_text("Query")#first the query
    for i in range(len(aux)):
        ax[i+1].imshow(all_images[aux[i][1]])#then images found
        ax[i+1].title.set_text("Distance: {0:.3f}".format(aux[i][0]))#distance as tittle
    plt.show()

ims,aux,im,distances = retrieve_k_images_from_X(query_1,X,3)
plot_retrieve(ims,aux,im,distances)
ims,aux,im,distances = retrieve_k_images_from_X(query_2,X,3)
plot_retrieve(ims,aux,im,distances)
ims,aux,im,distances = retrieve_k_images_from_X(query_3,X,3)
plot_retrieve(ims,aux,im,distances)

# %% [markdown]
# ## Exercise 5.6 Compute the accuracy of the algorithm: given a query image.
#
# Make a function
#
# ```
# accuracy(X, class_labels, k=5, query=x, class_query=y)
# ```
#
# That takes as input a the dataset `X`, the `class_labels` for the images, the number of images to retrieve `k`, a query image `x` and the class of the query image `y`. Returns as output the number of retrieved images that belong to class `y` divided by the total of images retrieved `k` (this is the accuracy).
#
# **Hint**: be careful to exclude the query image from the retrieved images.
#
# - Compute the accuracy with k=4 with the previous images. Does the accuracy match the images retrieved from the previous exercise?

# %%
class_labels = np.concatenate((np.zeros(30), np.ones(30),  2*np.ones(30))).reshape(90,1)

# %%
def accuracy(X, class_labels, k, query, class_query):
    
    distances = []
    closest_to_query = None
    closest_images =None
    q = None
    #same process
    for i in range(len(X)):
        if(np.array_equal(query,X[i])):#this time we dont want to add the image that we query
            q = all_images[i],i
        else:
            dist = np.linalg.norm(np.abs(query - X[i]))
            distances.append(dist)
    k_closests = list(np.argpartition(distances, k)[:k])
    aux = [(distances[i],i) for i in k_closests]
    aux.sort()
    closests_images = [all_images[item[1]] for item in aux]
    
    plot_retrieve(closests_images,aux,q[0],distances)
    acc = 0
    #if class_labeled are found in the closests we add count
    for i in k_closests:
        if class_labels[i] == class_query:
            acc += 1
    return acc/k#accuracy

print(str(100*accuracy(X,class_labels,4,query_1,0))+"%")
print(str(100*accuracy(X,class_labels,4,query_2,1))+"%")
print(str(100*accuracy(X,class_labels,4,query_3,2))+"%")
# Out:
# 0.0%
# 25.0%
# 0.0%

# %% [markdown]
# ## Exercise 5.7 Image retrieval based on texture and color.
#
# Make a function ` lm_features_rgb(image, filter_bank)`  that returns the features from the filter bank concatenated per color. If the previous feature vectors had 49 components now they will have 49*3 components.

# %%
def lm_features_rgb(image, filter_bank):

    n_filters = len(filter_bank)-1
    features_for_im = np.zeros(3*n_filters)#rgb feature vector
    
    im_conv = np.array(image[:,:,0])#red image
    features_for_im[:n_filters] = features_from_filter_bank(im_conv,filter_bank,n_filters)#feature vector with slicing
    
    im_conv = np.array(image[:,:,1])#green image
    features_for_im[n_filters:2*n_filters] = features_from_filter_bank(im_conv,filter_bank,n_filters)#slicing
    
    im_conv = np.array(image[:,:,2])#blue image
    features_for_im[2*n_filters:3*n_filters] = features_from_filter_bank(im_conv,filter_bank,n_filters)#slicing
        
    return features_for_im

# %%
# %%time 
lm_rgb_features = lm_features_rgb(all_images[0], filter_bank)
len(lm_rgb_features)
# Out:
# CPU times: user 17.9 s, sys: 1.14 s, total: 19.1 s
# Wall time: 19.1 s
# 144

# %% [markdown]
# ## Exercise 5.8 Apply the function to all the images in the dataset
#
# Using ` lm_features_rgb(image, filter_bank)` build the features of all the datapoints in and save them in `X_lm_rgb`.
# You can parallelize the feature building process using `joblib.Parallel`. This will make the computation much faster if you have a processor with more than two threads.

# %%
from joblib import Parallel,delayed
from tqdm import tqdm #delete tqdm(list) to list if dont want to control the time
#@13min
X_lm_rgb = Parallel(n_jobs = -1)(delayed(lm_features_rgb)(im,filter_bank) for im in tqdm(all_images))#matrix rgb

X_lm_rgb
# Out:
# 100%|██████████| 90/90 [13:12<00:00,  8.80s/it]
# [array([1.07455808e+02, 1.06071654e+02, 9.12758049e+01, 8.22769886e+01,
#         7.62441209e+01, 6.00574495e+01, 1.09438881e+02, 1.07096394e+02,
#         8.74760890e+01, 7.20116793e+01, 6.97706755e+01, 4.66416509e+01,
#         1.07334991e+02, 1.10378472e+02, 7.93174321e+01, 6.72108586e+01,
#         5.97402936e+01, 3.49275963e+01, 4.88562973e+01, 4.38610717e+01,
#         5.01577494e+01, 5.98315183e+01, 5.34607402e+01, 4.50228062e+01,
#         1.34029356e+01, 8.42159880e+00, 1.30380366e+01, 2.80525568e+01,
#         1.78336490e+01, 1.06182528e+01, 1.85448232e-03, 7.10227273e-04,
#         5.17676768e-02, 2.60120739e+00, 1.20486111e+00, 1.60984848e-01,
#         1.25584833e+02, 1.30663037e+02, 1.27295021e+02, 1.27601050e+02,
#         1.16417614e+02, 1.09575442e+02, 7.28827730e+01, 5.45014994e+01,
#         7.28827730e+01, 3.33101326e+01, 1.02418718e+01, 5.68734217e-01,
#         1.02008878e+02, 1.00940459e+02, 8.75605271e+01, 7.64972775e+01,
#         6.99019492e+01, 5.68211016e+01, 1.05265625e+02, 1.03303267e+02,
#         8.41409801e+01, 6.86526199e+01, 6.32370186e+01, 4.15991162e+01,
#         1.05968789e+02, 1.08220328e+02, 7.52246686e+01, 6.20141256e+01,
#         5.46421244e+01, 3.09888731e+01, 4.76480824e+01, 4.27178425e+01,
#         4.86741635e+01, 5.86000237e+01, 5.13347538e+01, 4.36633523e+01,
#         1.30983270e+01, 7.92380840e+00, 1.18174716e+01, 2.32779751e+01,
#         1.29327257e+01, 9.42542614e+00, 1.93339646e-03, 1.34154040e-03,
#         2.12949811e-01, 1.87156723e+00, 1.25501105e+00, 2.71661932e-01,
#         1.29217921e+02, 1.33348524e+02, 1.27746054e+02, 1.27048690e+02,
#         1.17570076e+02, 1.10974590e+02, 7.38178267e+01, 5.52037169e+01,
#         7.38178267e+01, 3.37394255e+01, 1.03788668e+01, 9.94515467e-01,
#         1.00383799e+02, 9.58014520e+01, 8.39012390e+01, 7.62099116e+01,
#         6.91158065e+01, 5.60524779e+01, 9.84005682e+01, 9.32803030e+01,
#         8.32929293e+01, 6.87212753e+01, 6.36727036e+01, 4.10314867e+01,
#         9.75026831e+01, 9.45144413e+01, 7.62827888e+01, 6.48482481e+01,
#         5.53713699e+01, 3.06401515e+01, 4.92654672e+01, 4.32906013e+01,
#         4.73345960e+01, 5.83632418e+01, 5.00697206e+01, 4.31659564e+01,
#         1.35000395e+01, 1.04371843e+01, 1.41111506e+01, 2.17116083e+01,
#         1.41482797e+01, 1.15693655e+01, 7.37294823e-01, 9.88596907e-01,
#         1.33041351e+00, 3.16090593e+00, 1.66792929e+00, 5.33262311e-01,
#         1.16374605e+02, 1.22650095e+02, 1.22929017e+02, 1.27512390e+02,
#         1.14994279e+02, 1.09972538e+02, 7.31451626e+01, 5.47026515e+01,
#         7.31451626e+01, 3.34308318e+01, 1.02797112e+01, 2.31912879e+00]),
#  array([ 84.23469066,  87.79450758,  81.24202967,  82.5250947 ,
#          75.47443182,  73.9227036 ,  78.30926452,  86.02541035,
#          72.24569918,  68.41327336,  55.25619476,  56.52817235,
#          81.03681345,  83.07875631,  62.76163984,  55.60329861,
#          44.68256787,  42.73015309,  70.83053188,  59.79304766,
#          61.09670928,  78.87381629,  66.27158302,  64.76014047,
#          23.74451547,  14.52935606,  15.62046244,  30.22967961,
#          17.69921875,  19.52750158,   3.72762784,   3.48650568,
#           1.62294823,  13.46393624,   5.96867109,   6.21472538,
#         133.48930713, 129.45142835, 127.64244003, 126.63261521,
#         127.80863321, 131.10412721,  87.23473011,  65.2578125 ,
#          87.23473011,  39.92294034,  12.34035669,  23.05697601,
#          87.94902146,  91.59816919,  83.43757891,  81.80121528,
#          73.92144097,  71.59816919,  82.78519571,  91.59260574,
#          75.51471749,  67.91181345,  58.64066446,  56.11754261,
#          85.44215593,  90.42542614,  67.36363636,  57.0385101 ,
#          47.41193182,  41.54486269,  70.88612689,  59.78243371,
#          61.15506629,  79.08850221,  66.46898674,  64.85531092,
#          23.14539931,  15.07528409,  16.2112137 ,  30.13273359,
#          18.97092014,  18.81230271,   3.8761048 ,   4.05074179,
#           2.6193971 ,  14.20920139,   6.18059501,   6.47703598,
#         123.85617898, 124.20103378, 123.37480271, 125.17641256,
#         131.75457702, 132.74060922,  88.32930871,  66.0806108 ,
#          88.32930871,  40.42874053,  12.49846117,  23.23046875,
#          94.27616004,  98.65025253,  88.76724274,  85.32449495,
#          73.97707544,  69.72115688,  89.91635101, 102.01475694,
#          83.57536301,  70.06131629,  64.00915404,  57.18821023,
#          90.4070786 , 104.12590751,  71.63616635,  62.11111111,
#          56.79162721,  41.0644334 ,  71.8744476 ,  61.39393939,
#          61.76893939,  79.46938131,  67.79675663,  65.93678977,
#          23.40609217,  15.42116477,  17.71097696,  29.642006  ,
#          18.25244634,  18.31873422,   3.84528883,   4.13072128,
#           2.72131471,  12.99755366,   5.94073548,   6.30744949,
#         114.03898359, 131.82982165, 135.54932134, 123.65672348,
#         141.65759154, 141.75536616,  94.33901515,  70.5856613 ,
#          94.33901515,  43.19491793,  13.38056345,  21.98855745]),
#  array([9.26695470e+01, 9.92214725e+01, 9.48866793e+01, 8.69193892e+01,
#         8.65238321e+01, 1.00723722e+02, 8.93131708e+01, 7.34672112e+01,
#         7.57510653e+01, 7.90471512e+01, 7.68965830e+01, 9.10389836e+01,
#         7.00427715e+01, 4.78303741e+01, 5.89966856e+01, 7.27639283e+01,
#         6.85884628e+01, 6.91200284e+01, 8.17301136e+01, 7.05705492e+01,
#         5.43824179e+01, 6.33988715e+01, 6.12393860e+01, 7.54611348e+01,
#         5.50380761e+01, 1.99932134e+01, 9.00544508e+00, 3.67545376e+01,
#         1.38106061e+01, 3.41706518e+01, 1.88731061e+01, 0.00000000e+00,
#         1.41927083e-01, 9.78310448e+00, 8.68095013e-01, 1.95166509e+00,
#         1.25571062e+02, 1.31648911e+02, 1.27359178e+02, 1.27134391e+02,
#         1.22618174e+02, 8.52170928e+01, 5.66422033e+01, 4.23315183e+01,
#         5.66422033e+01, 2.58286379e+01, 7.85570549e+00, 4.00903567e+00,
#         8.90192156e+01, 9.15392992e+01, 8.99050663e+01, 8.62292061e+01,
#         8.06488715e+01, 9.49129972e+01, 8.62126736e+01, 7.56568813e+01,
#         7.56267756e+01, 7.95523990e+01, 7.05704703e+01, 8.49620423e+01,
#         6.95301452e+01, 5.90698785e+01, 6.20021307e+01, 7.25333018e+01,
#         6.51678504e+01, 6.62407276e+01, 8.17582465e+01, 6.81976010e+01,
#         5.34838226e+01, 6.45990372e+01, 6.06504104e+01, 7.46594066e+01,
#         5.58788273e+01, 1.75519255e+01, 9.37815657e+00, 3.31934186e+01,
#         1.44843355e+01, 3.43566130e+01, 1.14546638e+01, 3.32031250e-01,
#         1.31865530e-01, 7.66106376e+00, 8.98437500e-01, 3.72095960e+00,
#         1.29354956e+02, 1.18800979e+02, 1.27758562e+02, 1.25833373e+02,
#         1.33734533e+02, 1.04071338e+02, 6.92160669e+01, 5.17593513e+01,
#         6.92160669e+01, 3.16199495e+01, 9.69700915e+00, 5.99869792e+00,
#         8.72825521e+01, 8.76261048e+01, 9.01663905e+01, 8.49757339e+01,
#         7.68884549e+01, 9.39169034e+01, 7.93435922e+01, 7.88978851e+01,
#         7.99881234e+01, 7.88538510e+01, 6.47305082e+01, 7.69346591e+01,
#         6.96391651e+01, 7.44030934e+01, 6.81992977e+01, 7.44723801e+01,
#         6.16790956e+01, 6.01232244e+01, 8.57273516e+01, 6.79613715e+01,
#         5.38052399e+01, 6.73727509e+01, 6.23702257e+01, 7.46902225e+01,
#         5.09408933e+01, 1.80007102e+01, 1.00728772e+01, 2.96350616e+01,
#         1.64391967e+01, 3.22062027e+01, 1.46179372e+01, 2.73255997e+00,
#         1.14749053e+00, 5.10136521e+00, 4.94752210e-01, 7.72127525e+00,
#         1.19002762e+02, 1.35742109e+02, 1.23894137e+02, 1.29354364e+02,
#         1.05160945e+02, 1.14657236e+02, 7.62694129e+01, 5.70448627e+01,
#         7.62694129e+01, 3.48784722e+01, 1.07366635e+01, 1.00690104e+01]),
#  array([105.32666509, 100.85164141, 100.87511837,  85.5878709 ,
#          79.72522096,  82.04592803, 107.81640625,  94.77548927,
#          91.38005051,  74.59422348,  57.69322128,  57.65029198,
#          96.71070076,  93.82690183,  74.92128314,  62.31395991,
#          42.34363163,  32.58325442,  76.44937658,  75.4436553 ,
#          77.05393782,  79.20537405,  67.64247948,  68.83349116,
#          41.71235795,  21.89784564,  30.59607797,  37.96748737,
#          15.95821496,  25.62030461,  11.22896938,   4.10511364,
#           3.00276199,  10.57390309,   4.38415404,   4.720131  ,
#         125.71949968, 124.51487532, 124.04517835, 124.81151357,
#         131.55354324, 100.43213384,  66.78515625,  49.93118687,
#          66.78515625,  30.50106534,   9.34449968,  13.99487058,
#         106.82848011, 102.88660038, 101.52955335,  86.01258681,
#          80.82421875,  81.92617582, 108.68568497,  96.21472538,
#          93.06968119,  75.76578283,  55.07354798,  60.63596907,
#          99.40147569,  96.00382734,  73.76309975,  57.5716935 ,
#          40.99960543,  38.76294192,  78.03330177,  76.93864426,
#          76.20205966,  78.86284722,  67.66414141,  70.60041824,
#          42.46717172,  21.69961332,  30.7898911 ,  37.44093277,
#          14.18615846,  25.14973958,  12.19953441,   3.75295928,
#           3.40830177,   8.47020991,   3.69921875,   4.20426926,
#         126.64015152, 119.9628709 , 127.80595013, 127.24542298,
#         146.904869  , 112.36249211,  74.74206913,  55.89717487,
#          74.74206913,  34.16497001,  10.5067077 ,  10.52868529,
#         108.58826547, 103.85732323, 101.52130682,  85.91500947,
#          80.25765467,  80.60886206, 110.08341225,  96.80014994,
#          92.16524621,  74.10535038,  51.86750316,  58.86627999,
#         101.0800584 ,  97.0053267 ,  71.58976484,  54.80464804,
#          41.1459517 ,  39.2787642 ,  78.18730271,  76.91840278,
#          76.04056187,  78.57926926,  68.24613321,  69.24968434,
#          40.80038668,  20.59031723,  29.9148911 ,  38.85416667,
#          13.99854009,  23.29371843,  11.60440341,   3.05871212,
#           2.77568655,   6.96886837,   2.45079703,   3.0449416 ,
#         127.89169034, 120.36671402, 127.08262311, 127.61213699,
#         147.56076389, 117.95576862,  78.47186711,  58.68746054,
#          78.47186711,  35.88581124,  11.05535827,   9.48287563]),
#  array([8.30780461e+01, 7.22901673e+01, 6.59801531e+01, 6.07684659e+01,
#         6.00935527e+01, 7.12615609e+01, 4.94038431e+01, 5.21446496e+01,
#         6.12625473e+01, 5.56220802e+01, 5.49725379e+01, 4.86365609e+01,
#         4.64367898e+01, 3.71180161e+01, 5.16399542e+01, 5.57660985e+01,
#         4.77687421e+01, 3.39821259e+01, 8.06483586e+01, 3.72539852e+01,
#         3.97895754e+01, 4.80021307e+01, 4.29112216e+01, 4.52358744e+01,
#         1.08125789e+01, 4.77556818e+00, 5.19519413e+00, 2.54618845e+01,
#         6.57299558e+00, 5.19582544e+00, 7.97624684e-01, 0.00000000e+00,
#         0.00000000e+00, 5.44314236e+00, 1.13817866e+00, 6.74124053e-01,
#         1.45471985e+02, 1.29631984e+02, 1.26814552e+02, 1.26317551e+02,
#         1.58831400e+02, 1.16763297e+02, 7.76741241e+01, 5.80929609e+01,
#         7.76741241e+01, 3.55148753e+01, 1.09337516e+01, 3.57481061e-01,
#         8.79434186e+01, 7.88609533e+01, 6.84086174e+01, 5.95546875e+01,
#         5.94728535e+01, 6.01681660e+01, 5.79644886e+01, 6.63737768e+01,
#         6.35333018e+01, 5.73517992e+01, 5.53034643e+01, 4.27364662e+01,
#         5.67028093e+01, 5.06528172e+01, 5.41989820e+01, 5.79516651e+01,
#         4.73883759e+01, 3.15830966e+01, 8.08198390e+01, 3.61302083e+01,
#         3.94309107e+01, 4.71498974e+01, 4.20363794e+01, 4.48130524e+01,
#         9.14610953e+00, 3.87764362e+00, 3.36355745e+00, 2.50097064e+01,
#         6.36975221e+00, 5.35061553e+00, 6.97403725e-01, 0.00000000e+00,
#         0.00000000e+00, 4.44389205e+00, 1.13758681e+00, 5.23200758e-01,
#         1.41537208e+02, 1.41717882e+02, 1.30977154e+02, 1.28357284e+02,
#         1.32343237e+02, 1.25545691e+02, 8.35337358e+01, 6.24872554e+01,
#         8.35337358e+01, 3.82134233e+01, 1.17894571e+01, 2.76870265e-01,
#         9.66426373e+01, 8.31236585e+01, 7.62552478e+01, 6.52391493e+01,
#         5.94818103e+01, 5.78923611e+01, 6.59816130e+01, 7.81301689e+01,
#         6.70425347e+01, 5.88463542e+01, 5.41841067e+01, 4.10717724e+01,
#         7.06775568e+01, 7.51246054e+01, 5.94438920e+01, 5.79246370e+01,
#         4.98368845e+01, 3.01197917e+01, 8.33444602e+01, 4.00642361e+01,
#         3.99769965e+01, 5.01867898e+01, 4.19101562e+01, 4.77904830e+01,
#         1.35664852e+01, 5.81135574e+00, 2.42597854e+00, 2.37355587e+01,
#         7.60965120e+00, 6.86904198e+00, 6.68757891e-01, 2.76199495e-04,
#         0.00000000e+00, 3.17412405e+00, 1.68067393e+00, 7.44554924e-01,
#         1.61622120e+02, 1.36039260e+02, 1.24849826e+02, 1.27729956e+02,
#         1.26389007e+02, 1.35471354e+02, 9.01438999e+01, 6.74401436e+01,
#         9.01438999e+01, 4.12619555e+01, 1.27659407e+01, 3.56376263e-01]),
#  array([ 93.65151515,  91.7488952 ,  90.95825442,  90.10598169,
#         113.34311869, 118.1894334 ,  86.19799558,  84.20142835,
#          86.96042456,  86.33282039,  93.00777304, 102.85538984,
#          79.35475852,  75.40127841,  74.6193971 ,  77.81210543,
#          74.59303977,  87.47316919,  68.92305871,  65.41686395,
#          71.72155145,  82.30429293,  74.639244  ,  68.5100221 ,
#          27.86841067,  19.4897017 ,  24.07942708,  43.64188763,
#          28.48851799,  23.39674085,   2.53701073,   1.66078756,
#           1.77789615,   6.86541193,   5.06786616,   1.87357955,
#         128.79557292, 127.87681503, 125.15830177, 128.23879419,
#         153.38083965, 103.3987137 ,  68.7712279 ,  51.4229798 ,
#          68.7712279 ,  31.41358902,   9.63581124,   6.12180398,
#          96.16106376,  92.74435764,  92.78144729,  89.34122475,
#         111.95111269, 116.7661774 ,  88.56597222,  87.42507102,
#          89.26657197,  87.02683081,  90.00950915,  95.64563605,
#          82.38147096,  79.61225537,  78.46310764,  77.40767045,
#          70.26649306,  74.77710701,  66.81392045,  65.09915562,
#          71.6693892 ,  82.23224432,  74.44823232,  68.46026673,
#          25.24743529,  20.62736742,  22.70695234,  43.67597854,
#          28.56234217,  23.6863952 ,   2.97837753,   2.42538668,
#           1.38612689,   5.32698074,   4.51377052,   1.06861585,
#         130.61280777, 126.91208965, 127.89165088, 126.26345486,
#         145.85337753, 111.27809343,  74.02189867,  55.35973011,
#          74.02189867,  33.83388573,  10.41122159,   6.41051136,
#          98.03626105,  93.68454072,  94.96740846,  91.46855271,
#          98.29987374, 106.90261995,  89.46358112,  87.90104167,
#          91.09138258,  86.69302399,  79.47529987,  82.36150568,
#          79.86336016,  82.96555398,  79.56833965,  76.97439236,
#          65.03219697,  52.84773516,  67.3292298 ,  64.12160669,
#          71.63147096,  83.1149779 ,  74.13608744,  67.61963384,
#          22.7865767 ,  19.2502762 ,  19.88936237,  43.27892203,
#          26.87140941,  22.06624842,   3.04332386,   2.77825126,
#           1.55587121,   3.93319918,   3.2965988 ,   0.56526199,
#         131.17463699, 130.01913668, 125.26929451, 127.26980745,
#         143.02864583, 119.81968119,  79.71567235,  59.62354009,
#          79.71567235,  36.45549242,  11.24534407,   5.11620107]),
#  array([9.40122317e+01, 9.37981771e+01, 8.04192314e+01, 7.44300426e+01,
#         7.46787011e+01, 7.41624448e+01, 9.87938368e+01, 8.52926926e+01,
#         8.06907749e+01, 7.24361979e+01, 5.29000158e+01, 4.07365846e+01,
#         8.69901357e+01, 7.79388810e+01, 6.93031487e+01, 7.02567077e+01,
#         4.03351484e+01, 2.29323311e+01, 6.38833649e+01, 5.17971907e+01,
#         4.71948390e+01, 5.32460543e+01, 4.76179766e+01, 5.03144334e+01,
#         2.02509864e+01, 9.28148674e+00, 8.31352588e+00, 1.39256234e+01,
#         7.01302083e+00, 7.17013889e+00, 1.26262626e-03, 1.01621686e+00,
#         0.00000000e+00, 1.31392045e-02, 0.00000000e+00, 3.92400568e-01,
#         1.14860204e+02, 1.26789339e+02, 1.27715041e+02, 1.31345841e+02,
#         9.30682607e+01, 6.71979956e+01, 4.46323390e+01, 3.33289141e+01,
#         4.46323390e+01, 2.02950994e+01, 6.10775726e+00, 5.59564394e+00,
#         9.75943024e+01, 9.66203441e+01, 8.26708097e+01, 7.50918561e+01,
#         7.63253630e+01, 7.33185764e+01, 1.02940499e+02, 9.01080335e+01,
#         8.44159564e+01, 7.38805240e+01, 5.58468277e+01, 3.89718671e+01,
#         9.32693340e+01, 8.54640546e+01, 7.47199732e+01, 7.33126184e+01,
#         4.30590672e+01, 2.30608033e+01, 6.43478930e+01, 5.19298453e+01,
#         4.72649937e+01, 5.38819050e+01, 4.78350300e+01, 5.09096828e+01,
#         2.10589489e+01, 1.04033302e+01, 9.15277778e+00, 1.58252052e+01,
#         8.29450758e+00, 8.39255840e+00, 1.73058712e-01, 1.45928030e+00,
#         1.40861742e-01, 4.07907197e-01, 0.00000000e+00, 1.10677083e+00,
#         1.08275805e+02, 1.36279632e+02, 1.25293324e+02, 1.31132418e+02,
#         7.83519965e+01, 7.36851720e+01, 4.89549006e+01, 3.65729167e+01,
#         4.89549006e+01, 2.22895360e+01, 6.74565972e+00, 6.97821970e+00,
#         1.03689039e+02, 1.01480271e+02, 8.65848722e+01, 7.57181976e+01,
#         7.07815262e+01, 6.36624448e+01, 1.09931700e+02, 9.99371449e+01,
#         8.95584754e+01, 7.77418718e+01, 5.45013021e+01, 3.01509233e+01,
#         1.03979403e+02, 9.53279277e+01, 8.12822364e+01, 8.00286064e+01,
#         4.57571023e+01, 1.27687027e+01, 6.51494239e+01, 5.29923059e+01,
#         4.88527068e+01, 5.50799400e+01, 4.88536932e+01, 5.21174242e+01,
#         2.20437579e+01, 1.28558633e+01, 1.09093277e+01, 1.87484217e+01,
#         1.07943497e+01, 1.18566919e+01, 1.70146780e+00, 2.14532039e+00,
#         1.16753472e+00, 1.68051610e+00, 1.41335227e-01, 2.14571496e+00,
#         1.35149779e+02, 1.33631313e+02, 1.29837634e+02, 1.27973564e+02,
#         8.97920612e+01, 8.65098643e+01, 5.75064315e+01, 4.29807844e+01,
#         5.75064315e+01, 2.62314552e+01, 7.99589646e+00, 9.30074179e+00]),
#  array([6.10454940e+01, 7.05520044e+01, 6.31590909e+01, 4.85176373e+01,
#         4.91662326e+01, 5.20148753e+01, 5.18174716e+01, 6.65117582e+01,
#         6.39194681e+01, 4.13886521e+01, 4.35252131e+01, 4.43701862e+01,
#         4.95114031e+01, 6.18706597e+01, 5.35178741e+01, 4.11290246e+01,
#         3.71644965e+01, 3.41042061e+01, 4.11833965e+01, 3.09825205e+01,
#         3.79229009e+01, 4.39566367e+01, 3.74058554e+01, 3.36199100e+01,
#         2.11070470e+01, 9.77840909e+00, 7.03760259e+00, 2.20477825e+01,
#         4.78610322e+00, 1.07393071e+01, 1.10402462e+01, 2.40471117e+00,
#         0.00000000e+00, 4.39030934e+00, 1.49936869e-03, 1.16753472e+00,
#         1.52683554e+02, 1.31380485e+02, 1.23097656e+02, 1.22891809e+02,
#         1.62299440e+02, 1.00589923e+02, 6.68963068e+01, 5.00124290e+01,
#         6.68963068e+01, 3.05538194e+01, 9.36122948e+00, 5.13024779e+00,
#         5.88905461e+01, 7.26956676e+01, 6.42968355e+01, 4.61537642e+01,
#         4.62419113e+01, 4.79584912e+01, 5.87087674e+01, 7.03357008e+01,
#         6.34606218e+01, 4.18224432e+01, 4.40374053e+01, 3.55752841e+01,
#         5.55646701e+01, 6.56577099e+01, 4.97229324e+01, 4.01676531e+01,
#         3.71092172e+01, 2.65939078e+01, 4.21064157e+01, 3.05000000e+01,
#         3.70608033e+01, 4.40759943e+01, 3.72802241e+01, 3.24322522e+01,
#         1.96973643e+01, 7.74775095e+00, 6.77592330e+00, 2.28272175e+01,
#         4.98859691e+00, 1.03660827e+01, 6.27911932e+00, 2.35440341e+00,
#         0.00000000e+00, 3.76463857e+00, 1.26262626e-03, 1.26775568e+00,
#         9.97434501e+01, 1.22028961e+02, 1.32344066e+02, 1.33738479e+02,
#         1.23741043e+02, 1.12716343e+02, 7.49786143e+01, 5.60781645e+01,
#         7.49786143e+01, 3.42802241e+01, 1.05603693e+01, 3.18008207e+00,
#         6.93986348e+01, 7.35011048e+01, 6.78880208e+01, 4.89076705e+01,
#         4.91876973e+01, 5.23080019e+01, 6.20042614e+01, 7.37753709e+01,
#         7.24780224e+01, 4.21562105e+01, 4.41305240e+01, 3.93023201e+01,
#         5.92856297e+01, 7.07037958e+01, 5.76354167e+01, 4.19360006e+01,
#         3.76047191e+01, 2.04796402e+01, 4.54397491e+01, 3.28711332e+01,
#         3.72322443e+01, 4.57537090e+01, 3.76924716e+01, 3.41324179e+01,
#         2.12559975e+01, 7.94937658e+00, 4.98042929e+00, 2.23938605e+01,
#         4.68469855e+00, 1.15966698e+01, 5.65676294e+00, 1.73058712e+00,
#         0.00000000e+00, 4.02442393e+00, 8.28598485e-04, 8.14985795e-01,
#         1.41239307e+02, 1.41352509e+02, 1.28589844e+02, 1.21541233e+02,
#         1.44119594e+02, 1.22892795e+02, 8.17622711e+01, 6.11631944e+01,
#         8.17622711e+01, 3.74105114e+01, 1.15340515e+01, 9.33633207e-01]),
#  array([ 61.18836806,  76.65770991,  78.91725852,  83.9140625 ,
#          81.7020202 ,  73.36063763,  60.15581597,  64.60941446,
#          69.06198706,  71.2882339 ,  76.54174558,  56.96220013,
#          52.39208491,  46.95663668,  61.60535038,  63.36975221,
#          66.10112847,  40.28693182,  47.80729167,  48.68923611,
#          68.84741951,  77.38257576,  63.88821812,  46.65822285,
#          17.53409091,   9.90786774,  16.9299637 ,  40.76211332,
#          12.99790878,  11.13656092,   9.51972854,   0.87535511,
#           0.75757576,   8.11702967,   3.07579703,   1.21216067,
#         122.17732008, 130.84232955, 124.19622001, 128.37642045,
#          98.22455019, 140.21657986,  93.30843592,  69.81510417,
#          93.30843592,  42.72403725,  13.23192866,   5.3496291 ,
#          69.12235638,  84.20245423,  81.55902778,  82.97277462,
#          78.86750316,  68.42305871,  74.28807607,  81.72940341,
#          74.83897569,  72.65187027,  74.88407513,  52.42009943,
#          72.63912563,  67.14500473,  71.72060448,  66.15230429,
#          72.06328914,  38.06928662,  47.06648516,  47.21729009,
#          69.88486427,  77.96594855,  65.08120265,  46.26235006,
#          18.47837753,  12.04920297,  20.76337595,  46.68596117,
#          18.15770991,  12.35385101,  10.28637942,   0.68418561,
#           1.56526199,  14.73555871,   3.60140467,   1.36371528,
#         139.13514047, 134.97699653, 134.05318813, 132.38052399,
#         113.16856061, 146.0407197 ,  97.19065657,  72.72427399,
#          97.19065657,  44.51400726,  13.79517835,   7.30768624,
#          80.56297348,  87.13186553,  81.81833965,  84.13715278,
#          78.92073074,  66.09998422,  88.8364899 ,  89.83278093,
#          75.29020676,  72.62764362,  73.97833807,  50.02765941,
#          89.28815499,  82.18260732,  73.63695549,  68.49857955,
#          73.66248422,  38.5016572 ,  48.19227431,  48.188881  ,
#          71.06285511,  81.34631471,  66.85523201,  48.42874053,
#          19.19215593,  14.37547348,  24.09398674,  48.26854482,
#          22.76692708,  15.92416351,  10.89587279,   0.99652778,
#           5.11777936,  19.33199179,   6.33589804,   1.3847459 ,
#         121.75461648, 141.37326389, 119.77201705, 128.84572285,
#         145.24483112, 144.73121843,  96.3227983 ,  72.07082544,
#          96.3227983 ,  44.10807292,  13.6724274 ,  11.33439867]),
#  array([ 86.46413352,  85.69140625,  85.56131629,  74.51854482,
#          73.03787879,  78.4366714 ,  81.53977273,  82.07287721,
#          78.79675663,  68.95138889,  59.64318971,  59.19227431,
#          72.0064315 ,  73.46101641,  64.43122633,  56.35325915,
#          49.07942708,  38.14176926,  67.12922191,  46.73784722,
#          40.84260574,  46.30886995,  50.31100063,  47.24854009,
#          25.83459596,  11.75714173,  11.20411143,  19.71748737,
#          13.00895676,  16.67313763,  11.51207386,   1.59560448,
#           3.33211016,   6.123619  ,   2.81044823,   6.8259154 ,
#         142.75651042, 131.30105745, 133.42984533, 132.70419034,
#         154.8227983 , 107.88778409,  71.76542771,  53.66682449,
#          71.76542771,  32.7949416 ,  10.07299558,  11.58834438,
#          89.95837279,  92.31684028,  87.20044192,  73.14236111,
#          68.62937973,  74.38091856,  91.09592014,  89.28377525,
#          82.23713699,  70.37791982,  56.29738794,  52.98693971,
#          86.1568024 ,  86.28728693,  71.4771149 ,  62.34797191,
#          49.20221749,  30.89745107,  65.97301136,  48.04754577,
#          43.10523201,  44.85973011,  48.85728378,  46.80066288,
#          27.96429135,  12.9760101 ,  11.75410354,  21.64591225,
#          13.89827967,  17.21318655,  11.68548769,   2.02028093,
#           3.64587279,   6.96046402,   2.91114268,   6.35341698,
#         136.79711174, 127.06467014, 123.07516572, 129.59552557,
#         130.81403883, 111.90475063,  74.44128788,  55.66856061,
#          74.44128788,  34.02466067,  10.45857008,   7.93371212,
#          95.80808081,  96.49009628,  88.31944444,  72.46594855,
#          65.26329703,  66.84899779,  98.4436553 ,  93.73910985,
#          85.3057923 ,  71.29726957,  53.56021149,  46.57256155,
#          95.08214962,  94.95466383,  73.38056345,  65.1635101 ,
#          46.65581597,  27.79896622,  66.65778883,  48.32406092,
#          45.16248422,  46.98255997,  48.46910511,  47.6255524 ,
#          28.29900568,  12.7672822 ,  13.14756944,  24.16733744,
#          14.28413037,  17.48232323,  11.3068971 ,   4.10692866,
#           3.76586174,   7.73930713,   3.35467961,   5.97281408,
#         118.50773359, 115.40550032, 116.73595328, 122.42491319,
#         147.43355429, 119.98784722,  79.82540246,  59.70300663,
#          79.82540246,  36.50441919,  11.25540562,   6.72478693]),
#  array([7.69816525e+01, 7.45743766e+01, 6.42117661e+01, 6.20118766e+01,
#         7.78273753e+01, 8.10737058e+01, 7.53042140e+01, 6.38320312e+01,
#         4.87005208e+01, 4.20488873e+01, 6.94976326e+01, 8.78185764e+01,
#         6.94896622e+01, 5.75881866e+01, 3.77455808e+01, 4.13207071e+01,
#         4.64373027e+01, 9.26165562e+01, 5.25924085e+01, 4.76950363e+01,
#         3.29885969e+01, 4.69052241e+01, 5.14034880e+01, 4.72925347e+01,
#         4.61526594e+01, 1.65505051e+01, 7.26882102e+00, 1.34866241e+01,
#         9.21385732e+00, 3.94086174e+01, 2.91540404e+01, 3.53456439e-01,
#         9.05539773e-01, 6.39954230e-01, 7.68071338e-01, 2.08376342e+01,
#         1.09642558e+02, 1.26184935e+02, 1.31090515e+02, 1.27525450e+02,
#         9.17652699e+01, 5.26047980e+01, 3.49025016e+01, 2.60359454e+01,
#         3.49025016e+01, 1.58096591e+01, 4.68004261e+00, 2.00338542e+01,
#         7.26613400e+01, 7.27653093e+01, 6.09425110e+01, 5.76908144e+01,
#         7.49958570e+01, 8.15986427e+01, 7.03861269e+01, 6.37178030e+01,
#         5.06640230e+01, 4.21261048e+01, 5.76087437e+01, 8.56955887e+01,
#         6.57683870e+01, 5.44783775e+01, 4.43994634e+01, 3.97604956e+01,
#         4.34270044e+01, 7.60150331e+01, 5.04201783e+01, 4.60049321e+01,
#         3.73596512e+01, 4.90291982e+01, 5.38104877e+01, 4.62413589e+01,
#         4.11705335e+01, 1.29743529e+01, 8.17735953e+00, 2.57763179e+01,
#         1.05192156e+01, 3.55587121e+01, 2.19164694e+01, 3.01846591e-02,
#         7.25260417e-01, 1.60152304e+00, 9.13825758e-01, 1.48408696e+01,
#         1.13169113e+02, 1.23397609e+02, 1.28815025e+02, 1.28182923e+02,
#         1.31320391e+02, 8.51193971e+01, 5.65810843e+01, 4.22857086e+01,
#         5.65810843e+01, 2.57990451e+01, 7.86312342e+00, 1.52007970e+01,
#         7.38518782e+01, 6.98895597e+01, 5.96039694e+01, 5.53832860e+01,
#         6.20753235e+01, 7.23705019e+01, 6.55663273e+01, 6.27453441e+01,
#         4.73593355e+01, 3.72199337e+01, 3.96802004e+01, 6.27896938e+01,
#         6.26171480e+01, 5.48427241e+01, 4.26236585e+01, 3.27966383e+01,
#         3.17208018e+01, 4.32058870e+01, 5.66045218e+01, 4.45975379e+01,
#         4.17934817e+01, 5.74770754e+01, 5.39773122e+01, 4.81338384e+01,
#         3.14786932e+01, 7.41406250e+00, 9.55259628e+00, 3.01476089e+01,
#         1.42276673e+01, 2.57619555e+01, 1.29643703e+01, 0.00000000e+00,
#         1.57828283e-03, 9.58877841e+00, 1.29580966e+00, 6.18272569e+00,
#         1.42464055e+02, 1.32841185e+02, 1.29754380e+02, 1.30728575e+02,
#         1.35965357e+02, 1.14792574e+02, 7.63562973e+01, 5.71068103e+01,
#         7.63562973e+01, 3.49132734e+01, 1.07440420e+01, 9.79419192e+00]),
#  array([8.56541588e+01, 8.72030855e+01, 8.62959675e+01, 8.51132418e+01,
#         9.74451547e+01, 1.08005287e+02, 7.52094776e+01, 7.68101326e+01,
#         8.01565262e+01, 8.20051689e+01, 9.20244634e+01, 9.70279751e+01,
#         6.89655145e+01, 6.94744713e+01, 7.31642203e+01, 7.87527620e+01,
#         7.93141572e+01, 7.80502289e+01, 5.62509075e+01, 5.32634154e+01,
#         6.19664615e+01, 6.89313842e+01, 6.15467566e+01, 5.36459122e+01,
#         2.39905698e+01, 1.97005997e+01, 1.62825126e+01, 3.48648595e+01,
#         1.93924400e+01, 1.60952099e+01, 8.03199968e+00, 4.18580335e+00,
#         2.24905303e-03, 1.01317866e+01, 1.54103535e+00, 3.30058396e+00,
#         1.30135496e+02, 1.30164654e+02, 1.28259430e+02, 1.25810606e+02,
#         1.42028567e+02, 8.63613873e+01, 5.74069602e+01, 4.29045928e+01,
#         5.74069602e+01, 2.61803188e+01, 7.96906566e+00, 1.81390862e+01,
#         8.71306424e+01, 9.09743924e+01, 8.67550110e+01, 8.42767124e+01,
#         9.37114504e+01, 1.00295770e+02, 8.01385338e+01, 8.19017519e+01,
#         8.26653646e+01, 8.07289694e+01, 8.70298295e+01, 8.65213068e+01,
#         7.38679372e+01, 7.62663747e+01, 7.76346275e+01, 8.12713068e+01,
#         7.96974037e+01, 6.73173532e+01, 5.71038116e+01, 5.23938999e+01,
#         6.21381787e+01, 6.86616162e+01, 6.14660669e+01, 5.32461332e+01,
#         2.18470644e+01, 1.88861664e+01, 1.62566682e+01, 3.57884706e+01,
#         1.92600616e+01, 1.56055477e+01, 7.83001894e+00, 3.57185133e+00,
#         2.17013889e-03, 1.01601562e+01, 1.86304451e+00, 2.20375631e+00,
#         1.31335582e+02, 1.27996804e+02, 1.30037090e+02, 1.25413905e+02,
#         1.40857008e+02, 9.25398911e+01, 6.15250552e+01, 4.59937658e+01,
#         6.15250552e+01, 2.80771386e+01, 8.57607323e+00, 1.76865136e+01,
#         9.27137390e+01, 9.67470013e+01, 9.14932528e+01, 8.95767045e+01,
#         9.21039694e+01, 8.75096275e+01, 8.91924716e+01, 9.22185527e+01,
#         8.64232560e+01, 7.98734217e+01, 8.39014362e+01, 7.04880051e+01,
#         8.59719855e+01, 8.75290799e+01, 8.29639362e+01, 8.20443497e+01,
#         7.47277068e+01, 4.92133444e+01, 5.77827099e+01, 5.25034722e+01,
#         6.33575205e+01, 7.25219776e+01, 6.38704624e+01, 5.35968277e+01,
#         1.96322601e+01, 1.75586332e+01, 1.88244949e+01, 3.62087279e+01,
#         2.14701705e+01, 1.56584596e+01, 8.30247790e+00, 3.20963542e+00,
#         1.32930871e-01, 1.32015073e+01, 2.29648043e+00, 7.34493371e-01,
#         1.22702849e+02, 1.28360283e+02, 1.28920889e+02, 1.26717921e+02,
#         1.15944089e+02, 1.05659841e+02, 7.02718198e+01, 5.25497554e+01,
#         7.02718198e+01, 3.20998264e+01, 9.84201389e+00, 1.43820234e+01]),
#  array([ 89.32990057,  84.79060133,  79.06908933,  59.18813131,
#          82.50508996,  75.73516414,  94.00990372,  90.06822128,
#          86.46697443,  53.59599905,  77.26901831,  71.28760259,
#          86.78034249,  95.92175663,  82.44925821,  47.8105666 ,
#          64.99530461,  62.9321733 ,  68.02351641,  60.36225537,
#          41.22691761,  43.33139994,  39.53760259,  62.25461648,
#          43.47747001,  13.95288826,  13.56372317,  23.61975221,
#          17.70028409,  16.42120423,  16.26306029,   1.41867898,
#           2.72841698,  11.26471749,   6.11588542,   1.15116004,
#         112.52548927, 139.00556345, 126.22147254, 129.66118213,
#         123.18615846, 124.33037405,  82.71886837,  61.88056345,
#          82.71886837,  37.8434738 ,  11.68702652,  15.5390625 ,
#          86.19645676,  83.37855114,  79.30389836,  56.8747238 ,
#          80.07851957,  74.23563763,  84.90498737,  86.76096907,
#          89.31348643,  50.657631  ,  70.2974274 ,  67.56940499,
#          78.56482797,  94.25619476,  84.2965988 ,  41.30287247,
#          54.9846512 ,  59.33175505,  66.65770991,  56.51400726,
#          37.89958176,  38.9943971 ,  36.85428504,  58.36438605,
#          35.60270676,   9.61312342,   9.36383365,  18.85037879,
#          13.01459912,  11.3046875 ,  12.81778725,   0.45276989,
#           1.0061553 ,   5.63707386,   2.36560922,   0.35432449,
#         117.95359848, 137.94878472, 120.06490688, 125.71267361,
#         136.22151199, 110.96070076,  73.80886995,  55.1964173 ,
#          73.80886995,  33.73678188,  10.37176452,  11.13944129,
#          86.44207702,  81.31695865,  77.93982797,  50.70324337,
#          72.77943497,  70.50240688,  84.11446496,  88.39910827,
#          90.00157828,  42.17526831,  62.65739426,  59.98859691,
#          83.10475852,  98.94069602,  85.79312658,  34.50505051,
#          45.74029356,  48.33984375,  64.15498737,  49.79872948,
#          37.5376815 ,  38.93785511,  36.38806029,  50.34367109,
#          31.71776357,  11.80018939,   9.24585701,  17.72979798,
#          12.95789931,  12.63395676,  10.42069129,   1.04640152,
#           0.54454703,   4.00540562,   1.06652462,   0.59363163,
#         106.66895518, 145.47281408, 119.14867424, 136.47119634,
#         131.94030145,  98.74700126,  65.66189236,  49.09323706,
#          65.66189236,  29.97967961,   9.18738163,   9.26933396]),
#  array([ 84.53393308, 101.15806503,  98.01108744,  94.16493056,
#          83.48776831,  67.33337279,  91.97731218,  93.56790562,
#          89.68951231,  90.18276515,  61.31593277,  30.56340751,
#          95.68967014,  96.43718434,  75.78231534,  79.60116793,
#          46.62835385,  10.50481376,  47.20565025,  41.52473958,
#          65.75003946,  81.50935133,  64.59536774,  44.10475852,
#          10.43268624,   9.05086016,  27.90605271,  49.58128157,
#          25.95580808,   6.20000789,   0.74763258,   1.83451705,
#           6.14425505,  25.85704703,   2.73701862,   1.53941761,
#         132.22135417, 135.00954861, 127.3462358 , 127.66753472,
#         109.41816604,  86.5714173 ,  57.5465988 ,  43.00844381,
#          57.5465988 ,  26.24455492,   7.98717645,   7.97881155,
#          88.61537247, 100.89642519,  97.29340278,  93.84394729,
#          80.70904356,  64.09197443,  96.97561553,  96.15561869,
#          88.50544508,  87.3370423 ,  58.56684028,  29.83869949,
#         102.14701705, 102.73934659,  73.28420928,  77.04951862,
#          44.60345644,  10.2410827 ,  48.00145991,  41.65364583,
#          66.97770676,  82.82244318,  64.97443182,  45.12953756,
#          11.61671402,   8.92337437,  28.05011048,  49.78689236,
#          27.13699495,   6.49471275,   1.3456834 ,   2.08688447,
#           8.04932134,  27.54943971,   3.28231534,   1.85132576,
#         122.30737058, 127.08641098, 128.78551136, 126.01744003,
#         119.32402146,  94.16781092,  62.61371528,  46.80164931,
#          62.61371528,  28.57966383,   8.73626894,   9.13806029,
#          97.25063131, 101.94290562,  95.57054924,  93.30855429,
#          79.64717487,  61.86714804, 104.61517519,  98.93769729,
#          86.61852904,  86.5245423 ,  55.16102431,  28.38439078,
#         110.42842487, 108.86896307,  72.23441446,  75.69570707,
#          41.49341067,  10.53109217,  49.04383681,  41.96563289,
#          66.53089489,  83.13510101,  65.27252999,  45.94917929,
#          11.60929609,   8.38139205,  26.47814078,  50.28760259,
#          25.46077967,   6.30334596,   1.3537721 ,   1.80460859,
#           6.58940972,  26.03977273,   2.65897254,   1.42874053,
#         126.78306503, 129.59919508, 128.6077178 , 126.2885101 ,
#         120.40392203,  99.15593434,  65.93564552,  49.30188605,
#          65.93564552,  30.11067708,   9.22301136,   7.64563605]),
#  array([101.48208649, 101.0131392 ,  99.56368371, 104.46535669,
#         106.30851484, 111.46160827,  85.09019886,  85.3431976 ,
#          81.49143782,  81.27446338,  89.44661458, 100.39015152,
#          72.13652146,  74.62385574,  62.93576389,  65.54028567,
#          76.27221433,  94.08139994,  96.11355745,  81.03965436,
#          79.49345013,  87.77249053,  81.51242898,  87.08633207,
#          34.37543403,  20.15672348,  19.29509943,  25.63443024,
#          26.89425505,  26.47660196,   4.60692866,   3.57185133,
#           1.59142203,   5.70849116,   6.89824021,   2.51984691,
#         133.28168403, 128.5681029 , 126.70549242, 126.65475063,
#         127.82717803,  93.7009154 ,  62.30105745,  46.57220644,
#          62.30105745,  28.43536932,   8.68785511,   9.64768782,
#         100.52765941, 101.44128788,  99.8973327 , 102.85416667,
#         106.28495896, 113.36363636,  87.32473169,  88.62156723,
#          83.80583176,  79.75181503,  88.96318655, 102.25118371,
#          74.04300821,  79.75260417,  66.71638258,  60.98634785,
#          74.65427715,  95.13877052,  94.65972222,  80.74262153,
#          79.14685922,  87.23461174,  82.42100694,  87.47151199,
#          33.91646938,  19.87839331,  20.17151989,  26.12772254,
#          26.51815025,  26.34706439,   3.82043087,   2.67637311,
#           1.91370739,   6.43284407,   6.74704072,   2.53937816,
#         135.54020676, 126.92148043, 123.87882734, 127.482994  ,
#         125.22869318,  94.20052083,  62.63683712,  46.82161458,
#          62.63683712,  28.5884233 ,   8.73662405,   9.93615846,
#         102.58601641, 103.22352431, 105.21725063, 103.96472538,
#         106.88778409, 111.18647412,  82.10037879,  86.19787721,
#          87.62428977,  88.40167298,  94.28148674,  98.48401989,
#          68.73642677,  73.34027778,  73.11122948,  71.00702336,
#          79.89520202,  91.27197759,  95.13833649,  81.53582702,
#          80.140625  ,  86.46125316,  81.46563289,  87.13186553,
#          36.41331282,  23.88316761,  19.85874369,  25.03862847,
#          27.41244476,  26.41769255,   5.765625  ,   6.9157197 ,
#           1.25769413,   5.35645518,   8.2424637 ,   5.22218277,
#         134.66781092, 126.63431187, 129.75564236, 128.90822285,
#         128.13959912,  78.50856218,  52.17163826,  38.97825915,
#          52.17163826,  23.76803188,   7.20817551,  14.73110006]),
#  array([8.03990294e+01, 8.41196733e+01, 8.25726010e+01, 7.51764520e+01,
#         8.08706597e+01, 9.06134391e+01, 7.15186632e+01, 7.94897412e+01,
#         7.77746607e+01, 5.86345486e+01, 6.39313052e+01, 7.89480350e+01,
#         7.01748343e+01, 7.95726010e+01, 6.73000710e+01, 4.32310211e+01,
#         5.14097222e+01, 6.88976089e+01, 6.32518939e+01, 5.59466540e+01,
#         4.89353299e+01, 5.46222775e+01, 4.69597538e+01, 5.61178583e+01,
#         3.05795849e+01, 1.88186553e+01, 9.03413037e+00, 1.18201547e+01,
#         1.09080650e+01, 1.56272491e+01, 9.51065341e+00, 5.21488321e+00,
#         1.60984848e-01, 1.14709596e+00, 3.01846591e-01, 2.90778883e+00,
#         1.28226365e+02, 1.30838778e+02, 1.31779001e+02, 1.29497396e+02,
#         1.14236190e+02, 1.31417969e+02, 8.74431029e+01, 6.54154040e+01,
#         8.74431029e+01, 4.00215041e+01, 1.23778015e+01, 4.87223801e+00,
#         7.71758207e+01, 8.33180240e+01, 7.67507891e+01, 6.26365609e+01,
#         6.60618292e+01, 7.63449337e+01, 7.44283854e+01, 8.57484217e+01,
#         7.12324021e+01, 4.82630603e+01, 4.49775095e+01, 5.19890704e+01,
#         7.59414062e+01, 8.63098958e+01, 6.29865057e+01, 4.05855035e+01,
#         3.48161695e+01, 3.27885890e+01, 5.49523753e+01, 4.64234927e+01,
#         4.39300821e+01, 5.10510180e+01, 4.14010022e+01, 4.68000316e+01,
#         2.13458018e+01, 1.27542219e+01, 1.16085069e+01, 1.39381708e+01,
#         9.03618213e+00, 9.17893782e+00, 5.27911932e+00, 1.65258049e+00,
#         5.33262311e-01, 9.39196654e-01, 1.22316919e-03, 1.04655934e+00,
#         1.29120660e+02, 1.29829388e+02, 1.27785709e+02, 1.25703835e+02,
#         1.13072640e+02, 1.32773161e+02, 8.83481692e+01, 6.60960780e+01,
#         8.83481692e+01, 4.04335938e+01, 1.25037879e+01, 1.77967172e+00,
#         8.45559107e+01, 8.62879182e+01, 7.85058791e+01, 6.21271307e+01,
#         5.51023911e+01, 6.25392598e+01, 7.98500237e+01, 9.27495660e+01,
#         7.21818971e+01, 4.77226957e+01, 3.65896859e+01, 3.85269492e+01,
#         8.58107244e+01, 1.01894807e+02, 6.75686158e+01, 4.32031250e+01,
#         3.42062027e+01, 1.94079467e+01, 5.66604719e+01, 4.51564473e+01,
#         4.44076310e+01, 5.20251342e+01, 4.25720092e+01, 4.72791982e+01,
#         2.16873816e+01, 1.33734217e+01, 1.25564631e+01, 1.69345802e+01,
#         9.42578125e+00, 8.84086963e+00, 4.03097380e+00, 2.97285354e+00,
#         1.97447128e+00, 2.39232165e+00, 2.01231061e-02, 3.32780934e-01,
#         1.22221196e+02, 1.24079901e+02, 1.27503472e+02, 1.22999329e+02,
#         1.34929135e+02, 1.31306739e+02, 8.73708965e+01, 6.53646622e+01,
#         8.73708965e+01, 3.99842961e+01, 1.23581124e+01, 2.43509312e+00]),
#  array([6.84141809e+01, 6.84531645e+01, 6.22529198e+01, 4.06182528e+01,
#         3.23627289e+01, 3.66865925e+01, 6.09820865e+01, 6.43134075e+01,
#         5.78942156e+01, 2.93362926e+01, 2.57806976e+01, 2.90863715e+01,
#         5.99189157e+01, 6.74576231e+01, 5.06560527e+01, 2.10791509e+01,
#         2.26517519e+01, 2.40043797e+01, 4.03974511e+01, 3.11781092e+01,
#         2.44375789e+01, 2.67980982e+01, 2.29410511e+01, 2.91961016e+01,
#         1.74547822e+01, 7.38316761e+00, 4.33672664e+00, 6.50875947e+00,
#         4.35590278e+00, 7.98255997e+00, 3.12215909e+00, 0.00000000e+00,
#         0.00000000e+00, 1.12697285e+00, 0.00000000e+00, 0.00000000e+00,
#         1.45455335e+02, 1.27051649e+02, 1.30816248e+02, 1.21459399e+02,
#         1.41848879e+02, 1.10030895e+02, 7.31794113e+01, 5.47346907e+01,
#         7.31794113e+01, 3.34539536e+01, 1.02857086e+01, 1.87440814e+00,
#         7.08295455e+01, 6.79102746e+01, 5.23835227e+01, 3.46422822e+01,
#         2.64257418e+01, 2.58309265e+01, 6.76154514e+01, 6.05971433e+01,
#         4.31649700e+01, 2.55739031e+01, 1.77285748e+01, 1.75746133e+01,
#         6.07973879e+01, 5.93389362e+01, 3.47324021e+01, 1.63557449e+01,
#         1.24589252e+01, 9.63281250e+00, 4.08431581e+01, 2.73125395e+01,
#         2.18633207e+01, 2.53448548e+01, 2.05880287e+01, 2.65346433e+01,
#         9.96594855e+00, 3.82125947e+00, 3.03180240e+00, 5.48181029e+00,
#         2.87902462e+00, 3.36359691e+00, 4.89267677e-03, 0.00000000e+00,
#         0.00000000e+00, 6.03693182e-02, 0.00000000e+00, 0.00000000e+00,
#         7.53136443e+01, 1.00686987e+02, 1.22850971e+02, 1.28786971e+02,
#         9.75591856e+01, 1.11698035e+02, 7.42952967e+01, 5.55621843e+01,
#         7.42952967e+01, 3.39509549e+01, 1.04789694e+01, 4.97948232e-02,
#         7.68200363e+01, 6.95274621e+01, 5.04046323e+01, 3.67296007e+01,
#         3.53089094e+01, 3.78158933e+01, 6.68765783e+01, 5.95761127e+01,
#         4.54757734e+01, 2.33903093e+01, 1.74217566e+01, 2.89050663e+01,
#         6.41099669e+01, 6.48789852e+01, 4.22831045e+01, 1.41719539e+01,
#         9.42025726e+00, 1.28427241e+01, 4.31860006e+01, 2.64876105e+01,
#         2.16287484e+01, 2.59133917e+01, 2.05423374e+01, 2.47413194e+01,
#         6.24996054e+00, 1.61513573e+00, 1.95442708e+00, 3.80910669e+00,
#         2.01400726e+00, 2.35381155e+00, 2.76199495e-04, 0.00000000e+00,
#         0.00000000e+00, 1.45991162e-03, 0.00000000e+00, 0.00000000e+00,
#         1.11926018e+02, 1.04305477e+02, 1.38688368e+02, 1.08511324e+02,
#         1.17228141e+02, 1.14648635e+02, 7.62705177e+01, 5.70264757e+01,
#         7.62705177e+01, 3.48766572e+01, 1.06777936e+01, 1.17858270e-01]),
#  array([ 88.08467487,  92.91153725,  88.63963857,  88.96800032,
#          94.1931029 ,  88.53259154,  88.33968592,  88.28499842,
#          81.29872948,  85.62065972,  83.5853851 ,  68.51377052,
#          83.41161616,  81.06068497,  68.06833965,  75.76294192,
#          72.51566446,  44.79332386,  56.09248737,  49.94472064,
#          63.57015467,  75.56987847,  66.61044034,  52.4522964 ,
#          18.40672348,  13.47565499,  22.82047033,  42.55342487,
#          31.08798927,  16.15798611,   4.54020676,   3.99443655,
#           3.27174085,  13.85325915,   7.85002367,   1.00094697,
#         115.85440341, 125.66788984, 126.76167929, 128.40056818,
#         111.24143782, 126.59749842,  84.2257339 ,  63.00800979,
#          84.2257339 ,  38.53736585,  11.89958176,   5.67396622,
#          91.6964173 ,  97.03811553,  90.11730587,  89.30046559,
#          87.40415878,  71.52497633,  93.84173769,  95.29249527,
#          83.51195549,  83.9606613 ,  73.8035827 ,  51.04541509,
#          88.69507576,  90.90676294,  70.3024779 ,  71.68525095,
#          61.30650253,  27.12117266,  52.65916982,  47.17814867,
#          62.98836016,  75.79470486,  65.44740372,  49.71969697,
#          14.80898832,  11.99577809,  21.36620107,  40.75307765,
#          24.92684659,  12.15972222,   3.18110795,   2.51538826,
#           1.95387468,  11.3125    ,   5.38293087,   0.22265625,
#         135.77395044, 117.87101484, 130.40672348, 124.5376815 ,
#         118.06226326, 131.42514994,  87.4506392 ,  65.42554451,
#          87.4506392 ,  40.02324021,  12.37136995,   1.89966067,
#         104.46878946, 104.24372633,  92.60570549,  86.59552557,
#          78.65265941,  63.30871212, 108.19385259, 109.36584596,
#          90.73832071,  80.59548611,  62.97032828,  36.29541509,
#         107.93209438, 109.74996054,  80.56518308,  69.92791193,
#          46.83214962,  13.89208491,  52.46377841,  46.43122633,
#          62.76306029,  75.15415878,  64.51519097,  49.79876894,
#          14.50536616,  11.33151831,  19.62058081,  38.15139678,
#          22.62468434,  10.21271307,   2.67301926,   2.05255682,
#           1.37140941,  10.33408302,   3.70391414,   0.17163826,
#         112.81340751, 113.5463226 , 119.50619476, 123.63549558,
#         133.03922033, 135.99159564,  90.4913589 ,  67.70549242,
#          90.4913589 ,  41.42092803,  12.82587595,   1.39374211]),
#  array([8.04542693e+01, 8.28304530e+01, 7.73009785e+01, 7.35692077e+01,
#         8.16743608e+01, 9.65862137e+01, 6.79014757e+01, 7.13109612e+01,
#         6.13041746e+01, 5.70368924e+01, 6.14614110e+01, 7.94358823e+01,
#         5.99706439e+01, 5.99771938e+01, 5.38131313e+01, 4.57863794e+01,
#         5.18209438e+01, 6.45625000e+01, 6.44217566e+01, 4.73571654e+01,
#         4.62691367e+01, 5.59712753e+01, 4.80210701e+01, 4.84754972e+01,
#         2.17845644e+01, 1.26981534e+01, 6.37480271e+00, 1.95664457e+01,
#         6.61138731e+00, 1.32121212e+01, 4.76984691e+00, 2.90439552e+00,
#         0.00000000e+00, 1.25284091e+00, 1.20738636e-01, 1.24045139e+00,
#         1.24410866e+02, 1.29309304e+02, 1.25336016e+02, 1.29834833e+02,
#         1.39070391e+02, 1.18579979e+02, 7.88862058e+01, 5.90002762e+01,
#         7.88862058e+01, 3.60764678e+01, 1.11097696e+01, 2.87109375e+00,
#         8.17747396e+01, 8.38763021e+01, 7.81463068e+01, 7.25449811e+01,
#         7.66623264e+01, 8.81455966e+01, 6.82864978e+01, 7.09168245e+01,
#         6.15306581e+01, 5.67786458e+01, 5.50143229e+01, 6.42352036e+01,
#         5.75677478e+01, 6.05971433e+01, 5.40529908e+01, 4.66011679e+01,
#         5.13018071e+01, 4.87325600e+01, 6.47175663e+01, 4.60489662e+01,
#         4.65047348e+01, 5.46357718e+01, 4.64854403e+01, 4.71583018e+01,
#         2.00156645e+01, 1.11137153e+01, 5.52797506e+00, 1.88602431e+01,
#         6.05934343e+00, 1.22883128e+01, 3.02308239e+00, 2.54016730e+00,
#         0.00000000e+00, 7.69373422e-01, 6.03693182e-02, 9.98697917e-01,
#         1.24846985e+02, 1.28770912e+02, 1.31467330e+02, 1.28386245e+02,
#         1.25296599e+02, 1.26244634e+02, 8.39958965e+01, 6.28317156e+01,
#         8.39958965e+01, 3.84338305e+01, 1.18725537e+01, 1.98520360e+00,
#         9.19315420e+01, 9.71693892e+01, 9.19368687e+01, 7.49393150e+01,
#         7.29519413e+01, 7.50197285e+01, 8.44214804e+01, 9.41490294e+01,
#         7.47175663e+01, 6.00360243e+01, 5.29313842e+01, 5.59346196e+01,
#         8.06169508e+01, 9.61735322e+01, 6.26616951e+01, 4.71296954e+01,
#         4.70757181e+01, 4.09573864e+01, 6.65140073e+01, 4.92090041e+01,
#         5.12184738e+01, 5.87229719e+01, 5.09549795e+01, 5.06504893e+01,
#         2.88413431e+01, 1.62232876e+01, 8.48832071e+00, 2.20063131e+01,
#         8.69326073e+00, 1.92548138e+01, 8.99506787e+00, 4.98910985e+00,
#         2.44910038e-01, 1.75260417e+00, 7.84801136e-01, 3.88884943e+00,
#         1.18235243e+02, 1.19890704e+02, 1.26867424e+02, 1.32315617e+02,
#         1.47054096e+02, 1.36369081e+02, 9.07434896e+01, 6.78925979e+01,
#         9.07434896e+01, 4.15374053e+01, 1.28523122e+01, 5.21551452e+00]),
#  array([6.68785511e+01, 6.52397806e+01, 6.16192787e+01, 5.77922585e+01,
#         6.26117819e+01, 8.89504814e+01, 6.35804924e+01, 5.89610953e+01,
#         5.61900253e+01, 4.72125158e+01, 4.99284249e+01, 7.78449732e+01,
#         6.02535511e+01, 5.54351720e+01, 4.66784249e+01, 3.31059028e+01,
#         4.05411143e+01, 6.43160511e+01, 4.58156960e+01, 3.89985006e+01,
#         4.06439394e+01, 4.50809265e+01, 4.08738557e+01, 4.22182371e+01,
#         2.18924795e+01, 9.47668087e+00, 9.52501578e+00, 1.68821023e+01,
#         1.28843513e+01, 1.22764362e+01, 2.97624684e+00, 9.35724432e-01,
#         1.00615530e-02, 4.94515467e-01, 1.38849432e+00, 4.22585227e-01,
#         1.32612650e+02, 9.54222301e+01, 1.40844539e+02, 1.15570825e+02,
#         1.21052083e+02, 7.26685211e+01, 4.82789615e+01, 3.60536222e+01,
#         4.82789615e+01, 2.19809422e+01, 6.61991004e+00, 2.63596907e+00,
#         7.39849274e+01, 7.49896622e+01, 6.69080256e+01, 6.05158617e+01,
#         7.95429688e+01, 9.63721591e+01, 7.95835701e+01, 8.10378788e+01,
#         6.55959991e+01, 5.47586806e+01, 5.89468119e+01, 7.34733665e+01,
#         8.09191130e+01, 8.21614978e+01, 6.23907434e+01, 4.22946654e+01,
#         4.43131708e+01, 5.34773911e+01, 4.70610795e+01, 3.92216304e+01,
# ...
#         1.27622751e+02, 6.35592251e+01, 4.22054530e+01, 3.15108902e+01,
#         4.22054530e+01, 1.91696259e+01, 5.75224905e+00, 5.23946496e+00,
#         8.62370186e+01, 6.28460780e+01, 2.25779277e+01, 1.31490688e+01,
#         2.63289536e+01, 4.88109217e+01, 6.63497475e+01, 4.01792929e+01,
#         2.26874211e+00, 1.05934343e+00, 2.80046559e+00, 2.97131076e+01,
#         5.40967093e+01, 3.06603535e+01, 0.00000000e+00, 0.00000000e+00,
#         1.61773990e-02, 1.85510180e+01, 4.95346039e+01, 1.84631471e+01,
#         5.39078283e+00, 6.87156723e+00, 7.24917140e+00, 2.52144097e+01,
#         7.03941761e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00615530e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.23129972e+02, 1.33319247e+02, 1.41005800e+02, 1.18363439e+02,
#         6.13229561e+01, 3.04108270e+01, 2.01005366e+01, 1.49451152e+01,
#         2.01005366e+01, 8.99262153e+00, 2.53649779e+00, 0.00000000e+00]),
#  array([9.64266098e+01, 9.08597696e+01, 9.06985874e+01, 8.76242503e+01,
#         9.61653251e+01, 1.04014954e+02, 8.74526121e+01, 8.98901121e+01,
#         8.31951547e+01, 7.33848248e+01, 7.12987295e+01, 8.62886285e+01,
#         8.89360401e+01, 8.94085780e+01, 7.23538905e+01, 5.83041746e+01,
#         5.33583097e+01, 7.55169665e+01, 8.05537405e+01, 6.55138100e+01,
#         5.61930240e+01, 6.37283381e+01, 6.56195944e+01, 7.25145991e+01,
#         4.04362768e+01, 1.43571259e+01, 4.86631944e+00, 1.51238557e+01,
#         1.33879814e+01, 2.53976089e+01, 1.58257576e+01, 3.28874684e+00,
#         8.06502525e-02, 5.98208649e-01, 8.02398990e-01, 1.02756076e+01,
#         1.05448272e+02, 1.20688960e+02, 1.27868766e+02, 1.26150095e+02,
#         1.03211293e+02, 9.90368924e+01, 6.58570076e+01, 4.92382812e+01,
#         6.58570076e+01, 3.00750473e+01, 9.20991162e+00, 2.45809659e+01,
#         8.95742188e+01, 8.51246843e+01, 8.23258759e+01, 7.85134943e+01,
#         8.64027383e+01, 9.22571812e+01, 7.76608270e+01, 7.37556029e+01,
#         6.84164299e+01, 5.53898753e+01, 5.30540562e+01, 7.25398516e+01,
#         7.31846196e+01, 7.25645123e+01, 5.44442077e+01, 3.58362137e+01,
#         4.02621922e+01, 5.96392440e+01, 7.46391256e+01, 5.28003472e+01,
#         4.42006787e+01, 5.43040956e+01, 5.52874842e+01, 6.13333333e+01,
#         2.41921954e+01, 6.67574179e+00, 1.41844223e+00, 6.22983744e+00,
#         8.09580177e+00, 1.59645676e+01, 7.67400568e+00, 8.73974116e-01,
#         0.00000000e+00, 0.00000000e+00, 1.21291035e-01, 3.50891730e+00,
#         1.07271228e+02, 1.15300268e+02, 1.24019531e+02, 1.26666706e+02,
#         9.74838621e+01, 6.51465830e+01, 4.32648359e+01, 3.22997159e+01,
#         4.32648359e+01, 1.96672980e+01, 5.90155461e+00, 1.59321733e+01,
#         1.04298059e+02, 9.52810133e+01, 8.38386600e+01, 6.74526515e+01,
#         6.15456913e+01, 5.78251657e+01, 8.61012863e+01, 7.87623106e+01,
#         5.85435606e+01, 3.15717330e+01, 2.65668403e+01, 3.60348801e+01,
#         7.50497948e+01, 6.77189867e+01, 3.82026515e+01, 2.19857560e+01,
#         1.52361506e+01, 1.97617188e+01, 7.05686553e+01, 4.55691682e+01,
#         4.04105114e+01, 4.95827020e+01, 5.00587516e+01, 5.36440183e+01,
#         6.81624842e+00, 1.96638258e+00, 4.24834280e-01, 3.01152146e+00,
#         8.82773043e-01, 4.01795297e+00, 6.51041667e-03, 0.00000000e+00,
#         0.00000000e+00, 6.03693182e-02, 0.00000000e+00, 7.89141414e-04,
#         1.07328322e+02, 1.20562382e+02, 1.24512350e+02, 1.22174400e+02,
#         9.30759943e+01, 4.81303267e+01, 3.19185211e+01, 2.37990846e+01,
#         3.19185211e+01, 1.44365530e+01, 4.24376578e+00, 2.21216067e+00]),
#  array([107.88640309,  96.05318813,  87.32378472,  72.98607165,
#          88.16690341,  92.47577336,  98.74112216,  89.55228062,
#          80.69128788,  61.08459596,  78.64232165,  92.08727904,
#          98.22261679,  89.7014678 ,  68.57125947,  52.46531723,
#          66.16595644,  89.16512784,  68.89350537,  55.57374527,
#          31.92787247,  30.14086174,  38.5005524 ,  58.88880997,
#          42.61643782,  21.43327809,   4.38423295,   5.92664931,
#          11.12294823,  34.82694129,  27.84351326,   3.52402936,
#           0.        ,   0.        ,   2.11722696,  16.38620581,
#         111.01503314, 117.94523359, 125.84375   , 127.27154356,
#         101.15147569,  80.84481534,  53.73015309,  40.14752999,
#          53.73015309,  24.48717645,   7.42921402,  32.1411774 ,
#         107.3992661 ,  99.83692393,  86.24648832,  63.48737374,
#          82.52300347,  92.03511679, 107.07350852,  93.10412721,
#          76.41074811,  51.5566209 ,  66.45632102,  91.04375789,
#         100.26937342,  89.03357797,  60.50631313,  40.05898832,
#          45.56668245,  85.42759628,  62.02485795,  46.61643782,
#          27.46476484,  25.77801452,  30.75607639,  51.58029514,
#          35.91552241,  15.23082386,   1.16931029,   3.15171244,
#           6.89567551,  24.54281092,  25.52229324,   2.03476168,
#           0.        ,   0.        ,   1.12788037,   6.62953756,
#         114.9520202 , 123.48263889, 125.53270991, 125.85973011,
#         107.35049716,  69.32469223,  46.04869003,  34.39153251,
#          46.04869003,  20.94870581,   6.31640625,  20.48311237,
#         115.69985006, 105.84868213,  86.80602904,  59.14299242,
#          66.70407197,  73.76554609, 109.35858586,  86.99124053,
#          62.67305871,  40.06707702,  42.23895202,  56.82410038,
#          99.49822443,  76.17791193,  41.88581124,  28.8181029 ,
#          25.88099747,  45.38948074,  69.96752683,  46.33139994,
#          26.96594855,  24.34801136,  29.4274779 ,  53.19945549,
#          29.17451862,   3.45939867,   0.38249684,   1.49838226,
#           4.49270044,  12.49613321,   4.29525726,   0.        ,
#           0.        ,   0.        ,   0.62689394,   1.11683239,
#         129.13486427, 133.30871212, 128.85164141, 126.98015309,
#         127.79190341,  66.52896149,  44.1858428 ,  32.9946733 ,
#          44.1858428 ,  20.08992266,   6.03381471,   0.90467172]),
#  array([106.28424874, 100.10779672,  92.7985322 ,  82.68588226,
#          77.02963226,  78.90699968, 106.45782039,  94.58234691,
#          85.75520833,  81.64895044,  61.05295139,  68.58692393,
#         105.26317866,  92.82386364,  78.28326231,  75.26716383,
#          49.61541193,  54.67605745,  62.64626736,  47.28488005,
#          27.89922664,  25.17045455,  27.75252525,  46.11264994,
#          36.453125  ,  20.2882339 ,  12.34970802,  12.59146149,
#          10.97802241,  20.9272017 ,  15.28278883,   8.7318892 ,
#           3.68458018,   6.09686711,   6.17589962,   6.21922348,
#         120.40084438, 131.01203441, 122.59820865, 133.16583807,
#         123.68698706, 137.98133681,  91.82161458,  68.69748264,
#          91.82161458,  42.02718592,  13.01014047,   9.45580808,
#         106.37211963, 102.59986585,  94.02450284,  85.48670297,
#          77.34272412,  79.12310606, 105.71547506,  97.04008838,
#          89.36975221,  79.15522412,  60.00832544,  66.78211806,
#         103.61647727,  93.87689394,  84.33700284,  74.50426136,
#          51.59165878,  52.03302557,  59.5365767 ,  45.13644255,
#          25.52694918,  23.09864268,  26.97297191,  43.5309738 ,
#          31.9603851 ,  16.2287721 ,  11.51889994,  11.55922506,
#           9.70300663,  18.4235322 ,  12.10247001,   8.21590909,
#           2.21421244,   4.83806818,   5.40123895,   3.91477273,
#         115.82394255, 131.45837279, 122.18710543, 132.75232797,
#         112.52730429, 112.28839173,  74.69195865,  55.85858586,
#          74.69195865,  34.14101957,  10.50035511,   7.56218434,
#         101.60586332, 100.0407197 ,  90.02612058,  68.66362847,
#          53.52600221,  56.80066288,  93.6777541 ,  89.76148201,
#          78.0250947 ,  59.94144571,  34.87184343,  29.86493845,
#          88.75071023,  83.42909564,  71.10160196,  53.56624842,
#          29.49581755,  16.5764678 ,  54.66382576,  35.87661774,
#          19.88928346,  17.31494634,  22.26211332,  38.43166035,
#          19.94858744,   7.6227904 ,   2.29190341,   4.76136364,
#           4.60175979,   8.80946181,   4.89543876,   3.21346275,
#           0.        ,   0.33203125,   1.89417614,   1.66283933,
#         100.97679924, 116.32741477, 118.02091225, 126.61182134,
#          85.94286616,  63.97833807,  42.48690025,  31.7198548 ,
#          42.48690025,  19.31297348,   5.7963226 ,   0.74581755]),
#  array([6.25914220e+01, 6.16593277e+01, 5.72994792e+01, 3.92107008e+01,
#         6.01061395e+01, 8.92407276e+01, 6.87926926e+01, 7.58605982e+01,
#         5.62955729e+01, 3.46886443e+01, 4.44028567e+01, 6.95472301e+01,
#         7.75413510e+01, 8.60779277e+01, 4.88627683e+01, 3.13634391e+01,
#         3.78224037e+01, 5.87451862e+01, 3.82971117e+01, 3.26511206e+01,
#         1.64962910e+01, 1.54632260e+01, 1.57894571e+01, 3.09131550e+01,
#         2.14692629e+01, 8.10270676e+00, 2.68821023e+00, 3.45513731e+00,
#         1.12215909e+00, 9.34501263e+00, 1.09955808e+01, 4.22585227e-01,
#         2.36742424e-04, 1.30208333e-03, 0.00000000e+00, 7.25694444e-01,
#         1.06782749e+02, 1.14360914e+02, 1.18849235e+02, 1.25129261e+02,
#         9.58962674e+01, 8.34073548e+01, 5.54367503e+01, 4.14219145e+01,
#         5.54367503e+01, 2.52684659e+01, 7.68256787e+00, 1.15949337e+01,
#         6.15312500e+01, 6.23562973e+01, 5.73295455e+01, 3.31306424e+01,
#         4.81678898e+01, 6.92972696e+01, 6.77022569e+01, 7.79865846e+01,
#         5.90877525e+01, 2.82576152e+01, 2.94855587e+01, 5.02565104e+01,
#         7.43622554e+01, 9.03563368e+01, 4.92078598e+01, 2.42994003e+01,
#         1.94917535e+01, 3.49997238e+01, 3.80024069e+01, 3.31763731e+01,
#         1.62776199e+01, 1.58259549e+01, 1.56779119e+01, 3.15515704e+01,
#         2.23595723e+01, 5.40853851e+00, 2.80898832e+00, 4.02833018e+00,
#         1.81553819e+00, 7.45561080e+00, 1.09212042e+01, 6.43939394e-01,
#         0.00000000e+00, 3.22837753e-01, 0.00000000e+00, 8.04924242e-01,
#         1.03554648e+02, 1.13768190e+02, 1.23233310e+02, 1.23338621e+02,
#         8.51862374e+01, 8.23802872e+01, 5.47495265e+01, 4.09069602e+01,
#         5.47495265e+01, 2.49522964e+01, 7.57816446e+00, 7.78444602e+00,
#         7.76379419e+01, 7.47593119e+01, 6.13268624e+01, 2.78826547e+01,
#         2.85840041e+01, 2.89349747e+01, 8.09009628e+01, 8.27967172e+01,
#         6.11872238e+01, 2.07400568e+01, 1.02559975e+01, 1.83682528e+01,
#         8.32113321e+01, 9.57121212e+01, 4.97742266e+01, 1.75546480e+01,
#         7.05595013e+00, 1.08477746e+01, 4.04433396e+01, 3.30340909e+01,
#         1.53991083e+01, 1.55269097e+01, 1.51117030e+01, 3.10868056e+01,
#         2.24257023e+01, 1.59063289e+00, 2.27170139e+00, 2.77765941e+00,
#         1.52126736e+00, 1.92301926e+00, 4.52501578e+00, 0.00000000e+00,
#         0.00000000e+00, 1.81107955e-01, 1.40861742e-01, 0.00000000e+00,
#         8.59965278e+01, 1.12044231e+02, 1.16536064e+02, 1.22170099e+02,
#         6.58725931e+01, 7.74346591e+01, 5.14469302e+01, 3.84296086e+01,
#         5.14469302e+01, 2.34225458e+01, 7.10306187e+00, 1.28077652e-01]),
#  array([9.62200126e+01, 9.36099669e+01, 8.30062737e+01, 6.93145912e+01,
#         7.50280540e+01, 7.67301531e+01, 9.55568971e+01, 9.54083807e+01,
#         8.55523595e+01, 6.39942393e+01, 6.55279356e+01, 6.30362216e+01,
#         1.02365096e+02, 1.05324021e+02, 8.86347064e+01, 5.90798217e+01,
#         6.16688763e+01, 5.14151278e+01, 6.95501499e+01, 5.92354798e+01,
#         3.94893860e+01, 3.43404356e+01, 3.80442314e+01, 6.02022964e+01,
#         3.99253867e+01, 2.56947996e+01, 1.25150726e+01, 1.53983980e+01,
#         1.23804845e+01, 2.49060922e+01, 2.51961411e+01, 5.33846275e+00,
#         1.34154040e-02, 1.19448390e+00, 8.19523359e-01, 6.98035038e+00,
#         1.07392637e+02, 1.41763613e+02, 1.29465357e+02, 1.23218829e+02,
#         1.10146583e+02, 1.25408578e+02, 8.34376184e+01, 6.24134706e+01,
#         8.34376184e+01, 3.81728220e+01, 1.20956439e+01, 1.95335385e+01,
#         8.54300426e+01, 8.88906250e+01, 8.55275410e+01, 7.03814315e+01,
#         7.97018624e+01, 7.90866477e+01, 8.88267440e+01, 9.58785117e+01,
#         8.37182765e+01, 6.32112137e+01, 6.94309501e+01, 7.28691998e+01,
#         9.47722932e+01, 1.04695036e+02, 7.60695628e+01, 5.28366477e+01,
#         5.97500000e+01, 6.34618450e+01, 6.92390309e+01, 5.82895754e+01,
#         3.36073627e+01, 2.93669508e+01, 3.50372080e+01, 5.84148122e+01,
#         4.11773201e+01, 1.65147569e+01, 2.12776199e+00, 4.40751263e+00,
#         3.75710227e+00, 2.05889362e+01, 2.26805950e+01, 2.76692708e+00,
#         0.00000000e+00, 5.36616162e-03, 0.00000000e+00, 5.33712121e+00,
#         9.32327178e+01, 1.09611940e+02, 1.16454703e+02, 1.25908381e+02,
#         1.00791706e+02, 7.40406802e+01, 4.91947996e+01, 3.67528804e+01,
#         4.91947996e+01, 2.24051452e+01, 7.04707229e+00, 1.96708097e+01,
#         8.54519018e+01, 8.48149069e+01, 7.14371054e+01, 4.69894255e+01,
#         5.15166903e+01, 6.25134943e+01, 8.10956439e+01, 7.79407749e+01,
#         5.04282670e+01, 2.42253393e+01, 1.78371212e+01, 3.33277304e+01,
#         8.15948548e+01, 7.55732718e+01, 3.34812973e+01, 1.33575205e+01,
#         3.17649148e+00, 1.53936237e+01, 6.35823469e+01, 4.20325126e+01,
#         2.75872790e+01, 2.27738715e+01, 2.59599905e+01, 4.25460464e+01,
#         7.93059501e+00, 1.42183554e+00, 7.89141414e-05, 2.09122475e-03,
#         0.00000000e+00, 8.06463068e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         8.29694208e+01, 1.06636206e+02, 1.12179688e+02, 1.19278133e+02,
#         7.73718040e+01, 3.84344618e+01, 2.54492188e+01, 1.89512311e+01,
#         2.54492188e+01, 1.14547033e+01, 3.28026357e+00, 1.36126894e-02]),
#  array([6.15376420e+01, 6.13948469e+01, 5.44058554e+01, 3.23760653e+01,
#         4.19565183e+01, 5.91889994e+01, 6.56943261e+01, 7.17568261e+01,
#         6.13082386e+01, 2.54904119e+01, 3.21441761e+01, 5.17043876e+01,
#         6.82082544e+01, 8.17191840e+01, 5.92942708e+01, 2.25232797e+01,
#         2.03137232e+01, 4.27702020e+01, 2.38732639e+01, 1.70262784e+01,
#         7.92783302e+00, 5.62626263e+00, 8.84643308e+00, 1.58885338e+01,
#         1.62807765e+01, 7.38087910e+00, 1.71788194e+00, 2.84880051e-01,
#         1.78981218e+00, 9.52241162e+00, 8.94231376e+00, 3.04521780e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.22593119e+00,
#         1.02000079e+02, 1.08169942e+02, 1.19503867e+02, 1.22083176e+02,
#         1.00809107e+02, 1.34641375e+02, 8.95958412e+01, 6.70276199e+01,
#         8.95958412e+01, 4.10007102e+01, 1.26562500e+01, 9.71602746e+00,
#         5.66936948e+01, 5.60827415e+01, 4.61878157e+01, 2.60389441e+01,
#         3.26120975e+01, 5.19006866e+01, 6.14920297e+01, 6.27580887e+01,
#         4.82188289e+01, 2.09832307e+01, 2.20568182e+01, 4.36906960e+01,
#         6.00099826e+01, 6.92066761e+01, 4.18569287e+01, 1.67729246e+01,
#         1.34610953e+01, 3.36652068e+01, 1.97481850e+01, 1.48375158e+01,
#         5.64240057e+00, 4.28136837e+00, 6.75051294e+00, 1.28948074e+01,
#         1.17909959e+01, 4.68892045e+00, 1.38162879e+00, 5.06234217e-02,
#         6.70770202e-04, 4.27359533e+00, 4.09611742e+00, 1.95659722e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.69116951e+00,
#         9.08649779e+01, 1.07989623e+02, 1.12612176e+02, 1.20458728e+02,
#         1.12240017e+02, 6.69123658e+01, 4.44347380e+01, 3.31799637e+01,
#         4.44347380e+01, 2.01928662e+01, 6.07224590e+00, 4.57792771e+00,
#         2.86315499e+01, 2.09124842e+01, 1.04681581e+01, 5.65475063e+00,
#         6.22174874e+00, 1.12252210e+01, 1.56461884e+01, 7.19330019e+00,
#         1.65147569e+00, 7.06676136e-01, 5.30105745e-01, 1.96259470e+00,
#         5.65901199e+00, 2.02237216e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.80184659e-01, 1.67408065e+01, 8.99416035e+00,
#         3.36111111e+00, 2.48441446e+00, 4.30038668e+00, 9.19223485e+00,
#         1.23804451e+00, 3.72514205e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.50923295e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         6.42605350e+01, 1.26676531e+02, 1.51079506e+02, 8.29017124e+01,
#         3.19523753e+01, 1.57228930e+01, 1.03216540e+01, 7.60428504e+00,
#         1.03216540e+01, 4.45991162e+00, 1.06305240e+00, 0.00000000e+00])]

# %% [markdown]
# ## 5.9 Compute the accuracy of the method using lm rgb features
#
# Use the function implemented in 5.6 to compute the accuracy of the retrieved images using the features that contain color information. Make a plot of the 4 closest images to the query images in the `lm_rgb` space.
#
# - Is the accuracy higher?

# %% [markdown]
# # Yes we improved the accuracy by using a bigger feature vector

# %%
# compute (X_lm_rgb) and cast it as array
X_lm_rgb = np.array(X_lm_rgb)

query_1 = X_lm_rgb[6, :]#new queries
query_2 = X_lm_rgb[30,:]
query_3 = X_lm_rgb[65,:]

#checking accuracy
print(str(100*accuracy(X_lm_rgb, class_labels, 4, query_1, 0))+"%")
print(str(100*accuracy(X_lm_rgb, class_labels, 4, query_2, 1))+"%")
print(str(100*accuracy(X_lm_rgb, class_labels, 4, query_3, 2))+"%")
# Out:
# 75.0%
# 100.0%
# 50.0%
